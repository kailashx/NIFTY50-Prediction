# %%
# !pip install julia

import julia
from julia import Julia

julia.install()
julia.Julia(compiled_modules=False)

from julia import Main
Main.eval('using Pkg')
Main.eval('Pkg.add("IJulia")')
Main.eval('using IJulia')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 1.1 MB/s eta 0:00:00
# ...
# ---------------------------------------------------------------------------
# JuliaNotFound                             Traceback (most recent call last)
# <ipython-input-1-dce07408166c> in <cell line: 6>()
#       4 from julia import Julia
#       5
# ----> 6 julia.install()
#       7 julia.Julia(compiled_modules=False)
#       8
#
# /usr/local/lib/python3.10/dist-packages/julia/tools.py in install(julia, color, python, quiet)
#      76     """
#      77     if which(julia) is None:
# ---> 78         raise JuliaNotFound(julia, kwargname="julia")
#      79
#      80     libpython = linked_libpython() or ""
#
# JuliaNotFound: Julia executable `julia` cannot be found.
#
# If you have installed Julia, make sure Julia executable is in the
# system PATH.  Alternatively, specify file path to the Julia executable
# using `julia` keyword argument.
#
# If you have not installed Julia, download Julia from
# ...
