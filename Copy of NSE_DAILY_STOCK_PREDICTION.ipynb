# %%
#@title importing
# !pip install yfinance --upgrade --no-cache-dir
# !pip install gnewsclient python-Levenshtein

import pandas as pd
from gnewsclient import gnewsclient
from datetime import datetime as dtime
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.33)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.23.5)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.3.10)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.11.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2023.11.17)
# Collecting gnewsclient
#   Downloading gnewsclient-1.12-py3-none-any.whl (7.9 kB)
# Collecting python-Levenshtein
#   Downloading python_Levenshtein-0.23.0-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from gnewsclient) (2.31.0)
# Collecting fuzzywuzzy (from gnewsclient)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting feedparser (from gnewsclient)
#   Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 674.8 kB/s eta 0:00:00
# Collecting Levenshtein==0.23.0 (from python-Levenshtein)
#   Downloading Levenshtein-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (169 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.4/169.4 kB 4.2 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=3.1.0 (from Levenshtein==0.23.0->python-Levenshtein)
#   Downloading rapidfuzz-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 60.9 MB/s eta 0:00:00
# Collecting sgmllib3k (from feedparser->gnewsclient)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->gnewsclient) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->gnewsclient) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->gnewsclient) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->gnewsclient) (2023.11.17)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=10cf02f3108428d45d692cc3c83a21c84498830c640aaf78875c5f28ea41dcc5
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, fuzzywuzzy, rapidfuzz, feedparser, Levenshtein, gnewsclient, python-Levenshtein
# Successfully installed Levenshtein-0.23.0 feedparser-6.0.11 fuzzywuzzy-0.18.0 gnewsclient-1.12 python-Levenshtein-0.23.0 rapidfuzz-3.5.2 sgmllib3k-1.0.0

# %%
#@title CONSTANTS & DECLARATIONS
# Alpha vintage API key
API_KEY    = 'TCTO5BO9FQ42CQI2'
MAX_LEN    = 1800
IN_PERIOD  = '5d'
OUT_PERIOD = '1d'

eq         = r'/content/drive/MyDrive/EQUITY_L.csv'
sme        = r'/content/drive/MyDrive/SME_EQUITY_L.csv'
STOCK_INFO = r'/content/drive/MyDrive/STOCK_INFO/'
NEWS_PATH  = r'/content/drive/MyDrive/NEWS/'

current_time = dtime.now().strftime("%Y-%m-%d")

# %% [markdown]
# #Data Collection

# %%
#@title LOADING SYMBOLS

eq_list = pd.read_csv(eq)['SYMBOL']
sme_lis = pd.read_csv(sme)['SYMBOL']

# %%
#@title News Collection and Save
topics = ['Top Stories',
             'World',
             'Nation',
             'Business',
             'Technology',
             'Science',
             'Health']
def get_national_news():
  for loc in client.locations:
    for topic_ in topics:
        client = gnewsclient.NewsClient(language='en', location=loc, topic=topic_, max_results=100)
        news = client.get_news() # list containes dict
  national_news = list()
  for title in news:
    national_news.append(title['title']+'. ')
  return national_news

news = get_national_news()
#print("No of news: ", len(news), ", News: At Index[0] ", news[0], ", At Index[", len(news), "] ", news[len(news)-1])

def get_news():
    w_news = get_world_news()
    news = get_national_news()
    for t in w_news:
        news.append(t)
    return news
#len(get_news())

#@title saving news to file

NEWS_PATH += current_time+'.csv'
with open(NEWS_PATH, 'w') as f:
    for news in get_news():
        f.writelines(news+',')

# %%
#@title Collect Stock Price and Save
import yfinance as yf

def get_fundamental_info(ticker_name):
  """Divide the input dictinary into multiple seq with specified length.

  Args:
    ticker_name: A SYMBOL.

  Returns:
    info: A dict with basic information about the given symbol.
    hist: historical market data of period 1 day and interval of 1 min
  """
  # get basic data
  ticker = yf.Ticker(ticker_name)

  # get historical market data
  hist = ticker.history(period='1d', interval="1m")
  info = ticker.info
  return hist, info
#hist = get_fundamental_info('WIPRO.NS')

# importing os module
import os
import pickle

# Directory
directory = current_time

# Parent Directory path
parent_dir = STOCK_INFO

# Path
path = os.path.join(parent_dir, directory)

# Create the directory
# 'GeeksForGeeks' in
# '/home / User / Documents'
os.mkdir(path)
print("Directory '% s' created" % directory)
print("Fetching EQUITY Symbols")
for symbol in eq_list:
    hist, info = get_fundamental_info(symbol+'.NS')
    hist.to_csv(path+'/'+symbol+'.csv')
    with open(path+'/'+symbol+'_info.bin', 'wb') as f:
        pickle.dump(info, f)
print("=================================================\nFetching SME Symbols")
for symbol in sme_lis:
    hist, info = get_fundamental_info(symbol+'.NS')
    hist.to_csv(path+'/'+symbol+'.csv')
    with open(path+'/'+symbol+'_info.bin', 'wb') as f:
        pickle.dump(info, f)
# Out:
# Directory '2023-12-23' created
# Fetching EQUITY Symbols
# ERROR:yfinance:ANSALAPI.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:ATLANTA.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:HDIL.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:HINDNATGLS.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:INDLMETER.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:KALYANI.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:NIRAJISPAT.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:ORTEL.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:RCOM.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:RMCL.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:ROLTA.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:SANWARIA.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:SETUINFRA.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:VISASTEEL.NS: No price data found, symbol may be delisted (period=1d)
# ERROR:yfinance:WELSPUNIND.NS: No price data found, symbol may be delisted (period=1d)
# =================================================
# Fetching SME Symbols
# ERROR:yfinance:ROCKINGDCE.NS: No data found, symbol may be delisted
# ERROR:yfinance:SUNREST.NS: No data found, symbol may be delisted
# ERROR:yfinance:ROXHITECH.NS: No data found, symbol may be delisted
# ERROR:yfinance:BABAFP.NS: No data found, symbol may be delisted
# ERROR:yfinance:MICROPRO.NS: No data found, symbol may be delisted
# ERROR:yfinance:SARTELE.NS: No data found, symbol may be delisted
# ERROR:yfinance:MAITREYA.NS: No data found, symbol may be delisted
# ERROR:yfinance:TRANSTEEL.NS: No data found, symbol may be delisted
# ERROR:yfinance:PARAGON.NS: No data found, symbol may be delisted
# ERROR:yfinance:SHANTHALA.NS: No data found, symbol may be delisted
# ERROR:yfinance:ONDOOR.NS: No data found, symbol may be delisted
# ERROR:yfinance:RCDL.NS: No data found, symbol may be delisted
# ERROR:yfinance:WOMANCART.NS: No data found, symbol may be delisted
# ERROR:yfinance:ACSAL.NS: No data found, symbol may be delisted
# ERROR:yfinance:COMMITTED.NS: No data found, symbol may be delisted
# ERROR:yfinance:PLADAINFO.NS: No data found, symbol may be delisted
# ERROR:yfinance:KARNIKA.NS: No data found, symbol may be delisted
# ERROR:yfinance:SCML.NS: No data found, symbol may be delisted
# ERROR:yfinance:GOYALSALT.NS: No data found, symbol may be delisted
# ERROR:yfinance:OLIL.NS: No data found, symbol may be delisted
# ERROR:yfinance:CANARYS.NS: No data found, symbol may be delisted
# ERROR:yfinance:KONTOR.NS: No data found, symbol may be delisted
# ERROR:yfinance:VISHNUINFR.NS: No data found, symbol may be delisted
# ERROR:yfinance:EFACTOR.NS: No data found, symbol may be delisted
# ERROR:yfinance:ARABIAN.NS: No data found, symbol may be delisted
# ERROR:yfinance
# ERROR:yfinance:MILTON.NS: No data found, symbol may be delisted
# ERROR:yfinance:OMFURN.NS: No data found, symbol may be delisted
# ERROR:yfinance:BETA.NS: No data found, symbol may be delisted
# ERROR:yfinance:TIRUPATI.NS: No data found, symbol may be delisted
# ERROR:yfinance:CADSYS.NS: No data found, symbol may be delisted
# ERROR:yfinance:RMDRIP.NS: No data found, symbol may be delisted
# ERROR:yfinance:MANAV.NS: No data found, symbol may be delisted
# ERROR:yfinance:TRANSWIND.NS: No data found, symbol may be delisted
# ERROR:yfinance:ACCORD.NS: No data found, symbol may be delisted
# ERROR:yfinance:ASLIND.NS: No data found, symbol may be delisted
# ERROR:yfinance:PROLIFE.NS: No data found, symbol may be delisted
# ERROR:yfinance:GICL.NS: No data found, symbol may be delisted
# ERROR:yfinance:DRL.NS: No data found, symbol may be delisted
# ERROR:yfinance:AURDIS.NS: No data found, symbol may be delisted
# ERROR:yfinance:GRETEX.NS: No data found, symbol may be delisted
# ERROR:yfinance:JETKNIT.NS: No data found, symbol may be delisted
# ERROR:yfinance:AVSL.NS: No data found, symbol may be delisted
# ERROR:yfinance:PERFECT.NS: No data found, symbol may be delisted
# ERROR:yfinance:AHIMSA.NS: No data found, symbol may be delisted
# ERROR:yfinance:SHAIVAL.NS: No data found, symbol may be delisted
# ERROR:yfinance:EMKAYTOOLS.NS: No data found, symbol may be delisted

# %% [markdown]
# # Data Loading

# %%
hist, info = get_fundamental_info('CAPLIPOINT'+'.NS')

# %%
info
# Out:
# {'address1': 'Ashvich Tower',
#  'address2': '3rd Floor No.3, Developed Plots Industrial Estate Perungudi',
#  'city': 'Chennai',
#  'zip': '600096',
#  'country': 'India',
#  'phone': '91 44 2496 8000',
#  'fax': '91 44 2815 4952',
#  'website': 'https://www.caplinpoint.net',
#  'industry': 'Drug Manufacturers—Specialty & Generic',
#  'sector': 'Healthcare',
#  'longBusinessSummary': 'Caplin Point Laboratories Limited develops, produces, markets, and exports generic pharmaceutical formulations and branded products in India. It provides liquid and lyophilized vials, pre-filled syringes, 3-pc ophthalmic droppers, pre-mix bags, dry and liquid syrups-bottles, tables, soft gels, capsules, suppositories, liquid and emulsion injectables in ampoules and vials, topicals, and sachets. The company was incorporated in 1990 and is headquartered in Chennai, India.',
#  'fullTimeEmployees': 1642,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Dr. Sridhar  Ganesan',
#    'age': 67,
#    'title': 'MD & Whole Time Director',
#    'yearBorn': 1955,
#    'fiscalYear': 2023,
#    'totalPay': 8700000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. D.  Muralidharan',
#    'title': 'Chief Financial Officer',
#    'fiscalYear': 2023,
#    'totalPay': 9700000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Partheeban Vivek Siddarth',
#    'title': 'Chief Operating Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. G.  Venkatram',
#    'age': 40,
#    'title': 'General Counsel, Company Secretary & Compliance Officer',
#    'yearBorn': 1982,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. M. Sathya Narayanan',
#    'title': 'Deputy Chief Financial Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Ashok Gorekey Partheeban',
#    'title': 'Head of Marketing - Latam Business',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 1300.9,
#  'open': 1309.0,
#  'dayLow': 1302.1,
#  'dayHigh': 1421.2,
#  'regularMarketPreviousClose': 1300.9,
#  'regularMarketOpen': 1309.0,
#  'regularMarketDayLow': 1302.1,
#  'regularMarketDayHigh': 1421.2,
#  'dividendRate': 5.0,
#  'dividendYield': 0.0036000002,
#  'exDividendDate': 1694649600,
#  'payoutRatio': 0.08229999,
#  'fiveYearAvgDividendYield': 0.56,
#  'beta': 0.355,
#  'trailingPE': 25.704884,
#  'volume': 514755,
#  'regularMarketVolume': 514755,
#  'averageVolume': 132313,
#  'averageVolume10days': 147080,
#  'averageDailyVolume10Day': 147080,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 106758840320,
#  'fiftyTwoWeekLow': 575.0,
#  'fiftyTwoWeekHigh': 1421.2,
#  'priceToSalesTrailing12Months': 6.8072104,
#  'fiftyDayAverage': 1179.199,
#  'twoHundredDayAverage': 921.686,
#  'trailingAnnualDividendRate': 2.5,
#  'trailingAnnualDividendYield': 0.0019217464,
#  'currency': 'INR',
#  'enterpriseValue': 100925358080,
#  'profitMargins': 0.26646,
#  'floatShares': 18338961,
#  'sharesOutstanding': 75941696,
#  'heldPercentInsiders': 0.74594,
#  'heldPercentInstitutions': 0.01635,
#  'bookValue': 263.3,
#  'priceToBook': 5.339157,
#  'lastFiscalYearEnd': 1680220800,
#  'nextFiscalYearEnd': 1711843200,
#  'mostRecentQuarter': 1696032000,
#  'earningsQuarterlyGrowth': 0.253,
#  'netIncomeToCommon': 4179000064,
#  'trailingEps': 54.69,
#  'lastSplitFactor': '5:1',
#  'lastSplitDate': 1476835200,
#  'enterpriseToRevenue': 6.435,
#  'enterpriseToEbitda': 20.343,
#  'exchange': 'NSI',
#  'quoteType': 'EQUITY',
#  'symbol': 'CAPLIPOINT.NS',
#  'underlyingSymbol': 'CAPLIPOINT.NS',
#  'shortName': 'CAPLIN POINT LABOR',
#  'longName': 'Caplin Point Laboratories Limited',
#  'firstTradeDateEpochUtc': 1403495100,
#  'timeZoneFullName': 'Asia/Kolkata',
#  'timeZoneShortName': 'IST',
#  'uuid': '17f504dc-f993-32a2-a716-1a4f636b04bf',
#  'gmtOffSetMilliseconds': 19800000,
#  'currentPrice': 1405.8,
#  'recommendationKey': 'none',
#  'totalCash': 6873999872,
#  'totalCashPerShare': 90.54,
#  'ebitda': 4961099776,
#  'totalDebt': 33800000,
#  'quickRatio': 3.896,
#  'currentRatio': 5.669,
#  'totalRevenue': 15683200000,
#  'debtToEquity': 0.161,
#  'revenuePerShare': 206.628,
#  'returnOnAssets': 0.12794,
#  'returnOnEquity': 0.21962,
#  'grossProfits': 7891300000,
#  'freeCashflow': 727374976,
#  'operatingCashflow': 2593400064,
#  'earningsGrowth': 0.256,
#  'revenueGrowth': 0.142,
#  'grossMargins': 0.55419,
#  'ebitdaMargins': 0.31633,
#  'operatingMargins': 0.30639,
#  'financialCurrency': 'INR',
#  'trailingPegRatio': None}
