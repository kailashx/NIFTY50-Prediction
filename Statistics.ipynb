# %%
#@title Mean
def mean(arr):
    l = len(arr)
    sum = 0
    for e in arr:
        sum += e
    return sum/l

mean([1, 2, 3, 4, 5, 6, 7, 8, 9])
# Out:
# 5.0

# %%
#@title Median
def sort(arr):

    pass
def median(arr):
    le = len(arr)
    pos = int((le)/2)

    if le % 2 == 0:
        return (arr[pos]+arr[pos+1])/2

    return arr[pos]

median([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 5.5

# %%
#@title Range
def range(arr):
