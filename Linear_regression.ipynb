# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Research/Papers/alr3data.zip -d alr3data

# %%
import pandas as pd
df = pd.read_csv("/content/alr3data/heights.txt", sep=" ")

# %%
df
# Out:
#       Mheight  Dheight
# 0        59.7     55.1
# 1        58.2     56.5
# 2        60.6     56.0
# 3        60.7     56.8
# 4        61.8     56.0
# ...       ...      ...
# 1370     69.1     70.1
# 1371     65.0     71.6
# 1372     66.3     71.4
# 1373     70.8     71.0
# 1374     63.0     73.1
#
# [1375 rows x 2 columns]

# %%
# @title Scatter plot of mother's height vs daughter's height

df.plot.scatter(x='Mheight', y='Dheight')
# Out:
# <Axes: xlabel='Mheight', ylabel='Dheight'>

# %%
df_forbes = pd.read_csv("/content/alr3data/forbes.txt", sep=" ")
df_forbes
# Out:
#      Temp  Pressure   Lpres
# 0   194.5     20.79  131.79
# 1   194.3     20.79  131.79
# 2   197.9     22.40  135.02
# 3   198.4     22.67  135.55
# 4   199.4     23.15  136.46
# 5   199.9     23.35  136.83
# 6   200.9     23.89  137.82
# 7   201.1     23.99  138.00
# 8   201.4     24.02  138.06
# 9   201.3     24.01  138.04
# 10  203.6     25.14  140.04
# 11  204.6     26.57  142.44
# 12  209.5     28.49  145.47
# 13  208.6     27.76  144.34
# 14  210.7     29.04  146.30
# 15  211.9     29.88  147.54
# 16  212.2     30.06  147.80

# %%
# @title Pressure vs Temperature

import matplotlib.pyplot as plt
plt.scatter(df_forbes['Temp'], df_forbes['Pressure'])
plt.xlabel('Temperature')
_ = plt.ylabel('Pressure')

# %%
# @title Pressure vs Temperature

import matplotlib.pyplot as plt
plt.scatter(df_forbes['Lpres'], df_forbes['Temp'])
plt.xlabel('Temperature')
_ = plt.ylabel('Residuals')
